# %%
import sqlalchemy
import pandas as pd

# Get tweets from MYSQL database
dbServerName = "localhost"
dbUser = "root"
dbPassword = "woodycool123"
dbName = "azure_support_tweets"

engine = sqlalchemy.create_engine('mysql+pymysql://root:woodycool123@localhost:3306/azure_support_tweets')
df = pd.read_sql_table("predicted_tweets", engine)
data = pd.DataFrame(df)

print(data)
# Out:
# /Users/bethwalsh/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#                 id_tweet                                         text_tweet  \
# 0    1054057313659772928  @AzureSupport Yep getting it anytime I go into...
# 1    1054054251767443456  @AzureSupport https://t.co/1zcOle0rlE shows ev...
# 2    1054032991410778112  @AzureSupport @Azure Hey, I play the game Rain...
# 3    1054023209660661760                    @AzureSupport @allruiz Thanks!!
# 4    1054018246779813893  @allruiz @AzureSupport I managed to solve I hi...
# 5    1054009865985765378  @AzureSupport hello. I have made an inbound ru...
# 6    1054009407506386944  @azuresupport #azTechHelp Hi, my Ubuntu system...
# 7    1053983546237509633    @AzureSupport @AzureDevOps It does many thanks!
# 8    1053982639642869766  @AzureSupport The docs aren't super clear abou...
# 9    1053982431190179840  @AzureSupport Trying to figure out how to buil...
# 10   1053981091118362627  @AzureSupport Is there a slack or discord for ...
# 11   1053980832191270912     @AzureSupport Okay, I’ll check it.\nThank you.
# 12   1053948086500950017                  @AzureSupport Thanks bud. Will do
# 13   1053944331751481344  @AzureSupport Hi team, \nDoes "control plane c...
# 14   1053944080013688832  @AzureSupport Azure web app service with azure...
# 15   1053938210756280320  @azuresupport #azTechHelp MultipleActiveResult...
# 16   1053868250117881857  @AzureSupport It's not working in office machi...
# 17   1053866116806836224  Scale even further with Nested Deployments tod...
# 18   1053844232673214465  @azuresupport #azTechHelp: I have called some ...
# 19   1053843481418858497  @azuresupport #azTechHelp: I guess something h...
# 20   1053843152119902209  @azuresupport #azhelp: Delete your Teams free ...
# 21   1053835877577908224  @AzureSupport Can I easily migrate all the pro...
# 22   1053830989221310465  @AzureSupport I was actually only trying to se...
# 23   1053795701325529088                  @AzureSupport Sure I can do that.
# 24   1053794834312511488  Hi @AzureSupport. \nI took part in a machine l...
# 25   1053779837381435393  @AzureSupport @MrPeterLMorris @rembou1 Peter, ...
# 26   1053774099229667329  @AzureSupport @MrPeterLMorris @rembou1 Peter, ...
# 27   1053768427314253824  @AzureSupport  hello, I need to know how much ...
# 28   1053744984745218048  @azuresupport #azTechHelp I just started learn...
# 29   1053703231656857600  @AzureSupport I opened up a case, but the firs...
# ..                   ...                                                ...
# 799  1050502108997410817  @AzureSupport Still no action on the forum. En...
# 800  1050489737843236864  @YannickReekmans @AzureSupport It does seem to...
# 801  1050489316663681024  @AzureSupport is there a plan specific reason ...
# 802  1050482180688732161  I've been asked to update my IP addresses for ...
# 803  1050479170722156544  @andersaberg @AzureSupport I’m afraid this is ...
# 804  1050478855696322560  @andersaberg @AzureSupport That might be the i...
# 805  1050478247253868545  @YannickReekmans @AzureSupport Maybe it just d...
# 806  1050476903268831232  @azuresupport #azTechHelp My published cloud a...
# 807  1050476684481302528  @YannickReekmans @AzureSupport yes the App say...
# 808  1050476132334804993  @YannickReekmans @AzureSupport User account 'u...
# 809  1050475421811257344  @YannickReekmans @AzureSupport I did! Have to ...
# 810  1050472233645162496  #FunctionsAMA @AzureSupport If I just get a 40...
# 811  1050466618390794240  @andersaberg @AzureSupport Did you use the /co...
# 812  1050466510882398213  @azuresupport #azTechHelp My https://t.co/WwnB...
# 813  1050465549992583170  @azuresupport #azhelp: We've set up a policy-b...
# 814  1050465394933280769  @YannickReekmans @AzureSupport Thank you Yanni...
# 815  1050463578854223872  @AzureSupport Can't. Don't have a microsoft ac...
# 816  1050455597374685185  @AzureSupport the link for the mac version doe...
# 817  1050451686626643968  @andersaberg @AzureSupport I think you should ...
# 818  1050446701952024576  And that's a wrap!  Thanks to everyone who par...
# 819  1050444970073702402  @AzureSupport #Azure Poral is down in all regi...
# 820  1050444503994257408  @AzureSupport  I am getting errors hitting Sha...
# 821  1050441101532909568  @mattchenderson @AzureSupport @AzureFunctions ...
# 822  1050439675658231808  @ryandevacc @AzureFunctions @AzureSupport For ...
# 823  1050438853515980800  @tayalasavari @AzureFunctions @AzureSupport Th...
# 824  1050437477318762499  @azuresupport #azTechHelp Hello, how to reques...
# 825  1050436928108224512                  @AzureSupport any update on this?
# 826  1050431794242363393  @AzureSupport I know right? My whole stored pr...
# 827  1050429850329260039  @AzureSupport Failed to execute query. Error: ...
# 828  1050428694001606661  @AzureSupport I have no vms there, so how do I...
#
#        created_at_status  truncated              id_user          id_str_user  \
# 0    2018-10-21 17:10:21          0             28641832             28641832
# 1    2018-10-21 16:58:11          0              6276962              6276962
# 2    2018-10-21 15:33:42          0           3014229740           3014229740
# 3    2018-10-21 14:54:50          0             17312264             17312264
# 4    2018-10-21 14:35:07          0             17312264             17312264
# 5    2018-10-21 14:01:49          0            545199794            545199794
# 6    2018-10-21 13:59:59          0           3209110786           3209110786
# 7    2018-10-21 12:17:14          0            361939705            361939705
# 8    2018-10-21 12:13:37          0            361939705            361939705
# 9    2018-10-21 12:12:48          0            361939705            361939705
# 10   2018-10-21 12:07:28          0            361939705            361939705
# 11   2018-10-21 12:06:27          0  1011455656702849024  1011455656702849024
# 12   2018-10-21 09:56:19          0           1288065594           1288065594
# 13   2018-10-21 09:41:24          0  1011455656702849024  1011455656702849024
# 14   2018-10-21 09:40:24          0           1288065594           1288065594
# 15   2018-10-21 09:17:05          0           1288065594           1288065594
# 16   2018-10-21 04:39:05          0            256372445            256372445
# 17   2018-10-21 04:30:36          0             63201618             63201618
# 18   2018-10-21 03:03:39          0           2842846670           2842846670
# 19   2018-10-21 03:00:40          0           2842846670           2842846670
# 20   2018-10-21 02:59:21          0           2842846670           2842846670
# 21   2018-10-21 02:30:27          0            240768332            240768332
# 22   2018-10-21 02:11:01          0             14867021             14867021
# 23   2018-10-20 23:50:48          0   706181388148592640   706181388148592640
# 24   2018-10-20 23:47:21          0   706181388148592640   706181388148592640
# 25   2018-10-20 22:47:46          0   857476565436739584   857476565436739584
# 26   2018-10-20 22:24:58          0   857476565436739584   857476565436739584
# 27   2018-10-20 22:02:25          0            615287693            615287693
# 28   2018-10-20 20:29:16          0            256372445            256372445
# 29   2018-10-20 17:43:21          0             23587474             23587474
# ..                   ...        ...                  ...                  ...
# 799  2018-10-11 21:43:14          0  1030073472540651520  1030073472540651520
# 800  2018-10-11 20:54:05          0            109948781            109948781
# 801  2018-10-11 20:52:24          0             28916085             28916085
# 802  2018-10-11 20:24:03          0           2773699884           2773699884
# 803  2018-10-11 20:12:05          0             56497601             56497601
# 804  2018-10-11 20:10:50          0             56497601             56497601
# 805  2018-10-11 20:08:25          0            109948781            109948781
# 806  2018-10-11 20:03:05          0             91040881             91040881
# 807  2018-10-11 20:02:13          0            109948781            109948781
# 808  2018-10-11 20:00:01          0            109948781            109948781
# 809  2018-10-11 19:57:12          0            109948781            109948781
# 810  2018-10-11 19:44:31          0            236772879            236772879
# 811  2018-10-11 19:22:13          0             56497601             56497601
# 812  2018-10-11 19:21:47          0           3877950953           3877950953
# 813  2018-10-11 19:17:58          0           1146873140           1146873140
# 814  2018-10-11 19:17:21          0            109948781            109948781
# 815  2018-10-11 19:10:08          0            438654507            438654507
# 816  2018-10-11 18:38:25          0            438654507            438654507
# 817  2018-10-11 18:22:53          0             56497601             56497601
# 818  2018-10-11 18:03:04          0           3146766895           3146766895
# 819  2018-10-11 17:56:11          0            109701690            109701690
# 820  2018-10-11 17:54:20          0             14153463             14153463
# 821  2018-10-11 17:40:49          0            178937258            178937258
# 822  2018-10-11 17:35:09          0   773689435120660480   773689435120660480
# 823  2018-10-11 17:31:53          0  1049300288052645888  1049300288052645888
# 824  2018-10-11 17:26:25          0             42878690             42878690
# 825  2018-10-11 17:24:14          0   774900819225378816   774900819225378816
# 826  2018-10-11 17:03:50          0            274879881            274879881
# 827  2018-10-11 16:56:07          0            274879881            274879881
# 828  2018-10-11 16:51:31          0             86163882             86163882
#
#                               name_user screen_name_user  \
# 0    Kevin's Small Engine Repair, CISSP           tehkts
# 1                         Howard Keziah     HowardKeziah
# 2                   Jasim Mohammed Sali       JasimPerth
# 3                         Dennis Dennão         dennisrs
# 4                         Dennis Dennão         dennisrs
# 5                                 Alper         alperc92
# 6                           Vlaro Lopez       vlarolopez
# 7                          Jonny Fuller    Jonny_Waffles
# 8                          Jonny Fuller    Jonny_Waffles
# 9                          Jonny Fuller    Jonny_Waffles
# 10                         Jonny Fuller    Jonny_Waffles
# 11                                 夜之食國   yorunowosukuni
# 12                             jebanisa         jebanisa
# 13                                 夜之食國   yorunowosukuni
# 14                             jebanisa         jebanisa
# 15                             jebanisa         jebanisa
# 16                        Saravanakumar    saravana_star
# 17                          Dean Cefola   MSAzureAcademy
# 18                               BS How          BSHOW24
# 19                               BS How          BSHOW24
# 20                               BS How          BSHOW24
# 21                          Steve Mintz          sdm24x7
# 22                        Mark Macumber     markmacumber
# 23                             ANDY LEE      andygarylee
# 24                             ANDY LEE      andygarylee
# 25                      Azure Cosmos DB    AzureCosmosDB
# 26                      Azure Cosmos DB    AzureCosmosDB
# 27                              Jad Fhs        jad_fhs15
# 28                        Saravanakumar    saravana_star
# 29                         Eric Sampson         Serow225
# ..                                  ...              ...
# 799                        Gigi Mathews     GPolyMathews
# 800                        Anders Åberg      andersaberg
# 801                  Karefully Verded 📜      hammerstyle
# 802                      Kodey Crandall    KodeyCrandall
# 803                    Yannick Reekmans  YannickReekmans
# 804                    Yannick Reekmans  YannickReekmans
# 805                        Anders Åberg      andersaberg
# 806                        Kelly Murphy      CodeGuruToo
# 807                        Anders Åberg      andersaberg
# 808                        Anders Åberg      andersaberg
# 809                        Anders Åberg      andersaberg
# 810                        Martin Pitel         Pitel_IT
# 811                    Yannick Reekmans  YannickReekmans
# 812                UDXS David Markarian        UDXSDavid
# 813                         Neal Leslie      nleslie1970
# 814                        Anders Åberg      andersaberg
# 815                                  JC   Changethursday
# 816                                  JC   Changethursday
# 817                    Yannick Reekmans  YannickReekmans
# 818                       Azure Support     AzureSupport
# 819                              🕵Kris🏃     ironcladkris
# 820                        Bill Shipman      billshipman
# 821                Shankar Ramachandran       areshankar
# 822                       Asavari Tayal     tayalasavari
# 823                          ryandevacc       ryandevacc
# 824                              Rômulo           rml125
# 825                                🦆🌪⛵️          malldae
# 826                           Christine    ChrisinQueens
# 827                           Christine    ChrisinQueens
# 828                         Jakub Bares       jakubbares
#
#                      location_user  \
# 0                   NOT on a boat.
# 1                    Charlotte, NC
# 2
# 3                   São Paulo - SP
# 4                   São Paulo - SP
# 5
# 6      Madrid, Comunidad de Madrid
# 7                     Richmond, VA
# 8                     Richmond, VA
# 9                     Richmond, VA
# 10                    Richmond, VA
# 11
# 12
# 13
# 14
# 15
# 16                           India
# 17               Pennsylvania, USA
# 18
# 19
# 20
# 21                          NY. NY
# 22            Melbourne, Australia
# 23
# 24
# 25           Globally distributed!
# 26           Globally distributed!
# 27                  Beirut,Lebanon
# 28                           India
# 29                    Red Wing, MN
# ..                             ...
# 799
# 800                         Sweden
# 801
# 802                       Orem, UT
# 803                        Belgium
# 804                        Belgium
# 805                         Sweden
# 806
# 807                         Sweden
# 808                         Sweden
# 809                         Sweden
# 810                       Brisbane
# 811                        Belgium
# 812                   localhost:80
# 813                    Houston, TX
# 814                         Sweden
# 815  Same place as Carmen Sandiego
# 816  Same place as Carmen Sandiego
# 817                        Belgium
# 818
# 819                   New York, NY
# 820                   Lansdale, PA
# 821              Toronto, Ontario
# 822                   Bellevue, WA
# 823
# 824                  Natal, RN, BR
# 825
# 826           Forest Hills, Queens
# 827           Forest Hills, Queens
# 828                         Prague
#
#                                       description_user  \
# 0    Infosec. Beer. E30. Dadlife. Dreaming of doing...
# 1    Entrepreneur, Technology and Adrenaline Enthus...
# 2
# 3    Fala galera, beleza? \nSou de São Paulo e vou ...
# 4    Fala galera, beleza? \nSou de São Paulo e vou ...
# 5
# 6          Digital artist who works with color fields.
# 7    Avid gamer, esports enthusist, big ol nerd. Co...
# 8    Avid gamer, esports enthusist, big ol nerd. Co...
# 9    Avid gamer, esports enthusist, big ol nerd. Co...
# 10   Avid gamer, esports enthusist, big ol nerd. Co...
# 11
# 12
# 13
# 14
# 15
# 16
# 17   Microsoft Sr. FastTrack Engineer, specializing...
# 18
# 19
# 20
# 21   Software solutions engineer/transplated Texan ...
# 22   Technical Director at Codeware - my opinions a...
# 23
# 24
# 25   The official Twitter handle of Azure Cosmos DB...
# 26   The official Twitter handle of Azure Cosmos DB...
# 27
# 28
# 29   Digital plumber. Back-end/distributed systems ...
# ..                                                 ...
# 799
# 800  Maker of things. I'm Diabetic. And a developer...
# 801  Business, Tech, Politics, Economics, and occas...
# 802  Utah Valley University - Lecturer; Emerging Ed...
# 803
# 804
# 805  Maker of things. I'm Diabetic. And a developer...
# 806
# 807  Maker of things. I'm Diabetic. And a developer...
# 808  Maker of things. I'm Diabetic. And a developer...
# 809  Maker of things. I'm Diabetic. And a developer...
# 810  Microsoft Evangelist loving technology/cloud a...
# 811
# 812
# 813  Moderate Democrat/Vegetarian/history buff. The...
# 814  Maker of things. I'm Diabetic. And a developer...
# 815
# 816
# 817
# 818  The official Microsoft Azure account for impro...
# 819  I can't bear to look at it. Well, I can, I do,...
# 820
# 821  Specializes in the .NET Web Stack, Microsoft A...
# 822  Program Manager working on Microsoft Azure Fun...
# 823
# 824  TIM Beta 📱Me segue e eu te sigo! Me ajuda e eu...
# 825                           freetime IoT experiments
# 826  Cyclist (aspiring), backpacker, history nerd, ...
# 827  Cyclist (aspiring), backpacker, history nerd, ...
# 828  AI and machine learning enthusiast. Full stack...
#
#                     url_user  followers_count_user  favourites_count_user  \
# 0    https://t.co/4vQxvHydvx                    69                   1366
# 1     http://t.co/erCJhaFO19                  2031                    258
# 2                       None                     0                      0
# 3    https://t.co/EDXDEo1Cxc                   115                     14
# 4    https://t.co/EDXDEo1Cxc                   115                     14
# 5                       None                     0                     26
# 6    https://t.co/f77NjKypkt                  1401                    595
# 7                       None                   174                   3818
# 8                       None                   174                   3818
# 9                       None                   174                   3818
# 10                      None                   174                   3818
# 11   https://t.co/xvSLOK5voR                     0                      0
# 12                      None                    32                     29
# 13   https://t.co/xvSLOK5voR                     0                      0
# 14                      None                    32                     29
# 15                      None                    32                     29
# 16                      None                    61                     33
# 17                      None                    65                   1691
# 18                      None                     0                      0
# 19                      None                     0                      0
# 20                      None                     0                      0
# 21                      None                    46                     26
# 22    http://t.co/MZOIlc2zr2                   155                     29
# 23                      None                     3                      7
# 24                      None                     3                      7
# 25   https://t.co/Cu88nGnN5O                  5867                  24795
# 26   https://t.co/Cu88nGnN5O                  5867                  24795
# 27    http://t.co/pTflNA2bQI                    65                      5
# 28                      None                    61                     33
# 29                      None                    43                    390
# ..                       ...                   ...                    ...
# 799                     None                     0                      0
# 800   http://t.co/Y8e4aU375b                   460                   1352
# 801                     None                    70                   7277
# 802  https://t.co/hYRyONPFRF                   105                    717
# 803  https://t.co/mwOF5L9axq                   112                    299
# 804  https://t.co/mwOF5L9axq                   112                    299
# 805   http://t.co/Y8e4aU375b                   460                   1352
# 806                     None                    25                      4
# 807   http://t.co/Y8e4aU375b                   460                   1352
# 808   http://t.co/Y8e4aU375b                   460                   1352
# 809   http://t.co/Y8e4aU375b                   460                   1352
# 810                     None                   113                   2092
# 811  https://t.co/mwOF5L9axq                   112                    299
# 812  https://t.co/ZjyelhA6NI                    69                  36905
# 813                     None                  1067                   5950
# 814   http://t.co/Y8e4aU375b                   460                   1352
# 815                     None                    28                     15
# 816                     None                    28                     15
# 817  https://t.co/mwOF5L9axq                   112                    299
# 818   http://t.co/OdNOX1mEV9                 31193                   1717
# 819                     None                   129                    650
# 820                     None                    12                     14
# 821                     None                   151                     46
# 822                     None                   319                    232
# 823                     None                     0                      2
# 824  https://t.co/DSzI03LD4m                   454                    231
# 825                     None                     1                      3
# 826                     None                   219                   1407
# 827                     None                   219                   1407
# 828  https://t.co/IcA69Arzz1                   403                    613
#
#     lang_user bernoullinb_label multinomialnb_label
# 0          en                25                  25
# 1          en                25                  25
# 2          en               313                  25
# 3          en                49                   1
# 4          en               313                 313
# 5          en               313                  25
# 6          es                25                  25
# 7          en                49                  25
# 8          en                 1                 313
# 9          en               313                 313
# 10         en                49                 313
# 11         ja                 1                   1
# 12         en                49                   1
# 13         ja                49                  25
# 14         en               313                  25
# 15         en                49                  25
# 16         en                49                  25
# 17         en                49                  25
# 18         en                25                  25
# 19         en               313                 313
# 20         en                25                  25
# 21         en                49                  25
# 22         en                49                  25
# 23         en                49                 313
# 24         en                25                  25
# 25         en                49                  25
# 26         en                49                  25
# 27         en               313                 313
# 28         en                25                  25
# 29         en                25                  25
# ..        ...               ...                 ...
# 799        en                49                  25
# 800        en               313                 313
# 801        en                49                 313
# 802        en                25                  25
# 803        en                 1                 313
# 804        en               313                 313
# 805        en                49                  25
# 806        en               313                  25
# 807        en                49                  25
# 808        en                25                  25
# 809        en               313                 313
# 810        en                25                  25
# 811        en                25                  25
# 812        en                25                  25
# 813        en               313                  25
# 814        en                25                  25
# 815        en               313                 313
# 816        en                 1                  25
# 817        en                49                 313
# 818        en                49                 313
# 819        en                49                  25
# 820        en                49                  25
# 821        en                49                   1
# 822        en               313                 313
# 823        en                25                  25
# 824        pt               313                 313
# 825        en                49                  25
# 826        en                49                 313
# 827        en                49                  25
# 828        en               313                 313
#
# [829 rows x 16 columns]

# %%
# This is a level 1 heading
## This is a level 2 heading
This is some plain text that forms a paragraph.
Add emphasis via **bold** and __bold__, or *italic* and _italic_.

Paragraphs must be separated by an empty line.

* Sometimes we want to include lists.
 * Which can be indented.

1. Lists can also be numbered.
2. For ordered lists.

[It is possible to include hyperlinks](https://www.example.com)

Inline code uses single backticks: `foo()`, and code blocks use triple backticks:

```
bar()
```

Or can be intented by 4 spaces:

    foo()

And finally, adding images is easy: ![Alt text](https://www.example.com/image.jpg)
# Out:
#   File "<ipython-input-2-2963a1fa83fa>", line 3
#     This is some plain text that forms a paragraph.
#                      ^
# SyntaxError: invalid syntax

# %%
data.frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-33079f8ec39d> in <module>()
# ----> 1 data.frame()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'frame'

# %%
data.head()
# Out:
#               id_tweet                                         text_tweet  \
# 0  1054057313659772928  @AzureSupport Yep getting it anytime I go into...
# 1  1054054251767443456  @AzureSupport https://t.co/1zcOle0rlE shows ev...
# 2  1054032991410778112  @AzureSupport @Azure Hey, I play the game Rain...
# 3  1054023209660661760                    @AzureSupport @allruiz Thanks!!
# 4  1054018246779813893  @allruiz @AzureSupport I managed to solve I hi...
#
#      created_at_status  truncated     id_user id_str_user  \
# 0  2018-10-21 17:10:21          0    28641832    28641832
# 1  2018-10-21 16:58:11          0     6276962     6276962
# 2  2018-10-21 15:33:42          0  3014229740  3014229740
# 3  2018-10-21 14:54:50          0    17312264    17312264
# 4  2018-10-21 14:35:07          0    17312264    17312264
#
#                             name_user screen_name_user   location_user  \
# 0  Kevin's Small Engine Repair, CISSP           tehkts  NOT on a boat.
# 1                       Howard Keziah     HowardKeziah   Charlotte, NC
# 2                 Jasim Mohammed Sali       JasimPerth
# 3                       Dennis Dennão         dennisrs  São Paulo - SP
# 4                       Dennis Dennão         dennisrs  São Paulo - SP
#
#                                     description_user                 url_user  \
# 0  Infosec. Beer. E30. Dadlife. Dreaming of doing...  https://t.co/4vQxvHydvx
# 1  Entrepreneur, Technology and Adrenaline Enthus...   http://t.co/erCJhaFO19
# 2                                                                        None
# 3  Fala galera, beleza? \nSou de São Paulo e vou ...  https://t.co/EDXDEo1Cxc
# 4  Fala galera, beleza? \nSou de São Paulo e vou ...  https://t.co/EDXDEo1Cxc
#
#    followers_count_user  favourites_count_user lang_user bernoullinb_label  \
# 0                    69                   1366        en                25
# 1                  2031                    258        en                25
# 2                     0                      0        en               313
# 3                   115                     14        en                49
# 4                   115                     14        en               313
#
#   multinomialnb_label
# 0                  25
# 1                  25
# 2                  25
# 3                   1
# 4                 313

# %%
data.plot.bar()
# %motplotlib inline
data.plot.bar()
import plotly.plotly as py
import plotly.graph_objs as go
;

importimport  plotly.plotlyplotly.p  as py
import plotly.graph_objs as go

data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')

# %%
importimport  plotly.plotlyplotly.p  as py
import plotly.graph_objs as go

data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')
# Out:
#   File "<ipython-input-5-951674205cd6>", line 2
#     importimport  plotly.plotlyplotly.p  as py
#                        ^
# SyntaxError: invalid syntax
# ERROR! Session/line number was not unique in database. History logging moved to new session 2

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-77447cf9dd04> in <module>()
#       1
# ----> 2 import plotly.plotly as py
#       3 import plotly.graph_objs as go
#       4
#       5 data = [go.Bar(x=df.School,
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Bar(x=df.School,y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')
